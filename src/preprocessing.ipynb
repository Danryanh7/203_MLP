# %%
import pandas as pd

# %%
df = pd.read_csv('../data/nbaGames.csv')
filtered_df = df[['TEAM_CITY', 'PLAYER_ID', 'PLAYER_NAME', 'MIN', 'FG_PCT', 'FG3_PCT', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS']]
# Out:
# /var/folders/19/48sc_t714fz_96wrj2kckpy80000gn/T/ipykernel_25091/1590905023.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/nbaGames.csv')

# %%
selected_rows = filtered_df[filtered_df['PLAYER_NAME'] == 'LeBron James']
selected_rows
# Out:
#           TEAM_CITY  PLAYER_ID   PLAYER_NAME    MIN  FG_PCT  FG3_PCT  FT_PCT  \
# 276     Los Angeles       2544  LeBron James  34:00   0.524    0.000   0.900
# 837     Los Angeles       2544  LeBron James  36:33   0.542    0.250   0.750
# 1259    Los Angeles       2544  LeBron James  35:56   0.619    0.250   0.750
# 1738    Los Angeles       2544  LeBron James  42:47   0.560    0.273   0.500
# 1953    Los Angeles       2544  LeBron James  36:52   0.583    0.333   1.000
# ...             ...        ...           ...    ...     ...      ...     ...
# 666461        Miami       2544  LeBron James     29   0.250    0.250   0.833
# 667163        Miami       2544  LeBron James     27   0.545    0.000   0.500
# 667779        Miami       2544  LeBron James     20   0.625    0.000   0.500
# 668212        Miami       2544  LeBron James     26   0.545    0.000   0.889
# 668536        Miami       2544  LeBron James     23   0.417    0.000   0.000
#
# ...
